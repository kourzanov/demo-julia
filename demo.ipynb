# %%
versioninfo()
using FFTW, DSP, DataFrames, Query, Plots, StatsPlots; #plotlyjs()
const N=100
plot(1:N,1:N |> x->cos.(2pi*x/N)+im*sin.(2pi*x/N) |> fft |> x->abs.(x) |> fftshift)
# Out:
# Julia Version 1.1.0
# Commit 80516ca202 (2019-01-21 21:24 UTC)
# Platform Info:
#   OS: Linux (x86_64-pc-linux-gnu)
#   CPU: Intel(R) Xeon(R) CPU @ 2.30GHz
#   WORD_SIZE: 64
#   LIBM: libopenlibm
#   LLVM: libLLVM-6.0.1 (ORCJIT, haswell)
# Environment:
#   JULIA_PATH = /srv/julia
#   JULIA_DEPOT_PATH = /srv/julia/pkg
#   JULIA_VERSION = 1.1.0
#   JULIA_PROJECT = /home/jovyan

# %%
using Cxx
cxx"""#include <iostream>"""
cxx"""using namespace std;"""
icxx"""cout << 123+234 << endl;"""
#__current_compiler__ = Cxx.new_clang_instance()
# Out:
# 357
# (class std::basic_ostream<char> &) {
# }

# %%
using Pkg
Pkg.add("CSV")
using CSV
# Out:
#   Updating registry at `/srv/julia/pkg/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 % Resolving package versions...
#  Installed CBOR ────────────── v0.1.1
#  Installed SymPy ───────────── v1.0.11
#  Installed Codecs ──────────── v0.5.0
#  Installed DistributedArrays ─ v0.6.4
#  Installed Reactive ────────── v0.8.3
#  Installed Unitful ─────────── v0.18.0
#  Installed MAT ─────────────── v0.7.0
#  Installed ProtoBuf ────────── v0.8.0
#  Installed BufferedStreams ─── v1.0.0
#  Installed DataStructures ──── v0.17.8
#  Installed Primes ──────────── v0.4.0
#  Installed CMake ───────────── v1.1.2
#  Installed ConstructionBase ── v1.0.0
#  Installed CMakeWrapper ────── v0.2.3
#  Installed HDF5 ────────────── v0.12.5
#  Installed Blosc ───────────── v0.5.1
#   Updating `~/Project.toml`
#   [7f3e1038] + CBOR v0.1.1
#   [19ecbf4d] + Codecs v0.5.0
#   [aaf54ef3] + DistributedArrays v0.6.4
#   [23992714] + MAT v0.7.0
#   [3349acd9] + ProtoBuf v0.8.0
#   [a223df75] + Reactive v0.8.3
#   [24249f21] + SymPy v1.0.11
#   [1986cc42] + Unitful v0.18.0
#   Updating `~/Manifest.toml`
#   [a74b3585] + Blosc v0.5.1
#   [e1450e63] + BufferedStreams v1.0.0
#   [7f3e1038] + CBOR v0.1.1
#   [631607c0] + CMake v1.1.2
#   [d5fb7624] + CMakeWrapper v0.2.3
#   [19ecbf4d] + Codecs v0.5.0
#   [187b0558] + ConstructionBase v1.0.0
#   [864edb3b] ↑ DataStructures v0.17.7 ⇒ v0.17.8
#   [aaf54ef3] + DistributedArrays v0.6.4
#   [f67ccb44] + HDF5 v0.12.5
#   [23992714] + MAT v0.7.0
#   [27ebfcd6] + Primes v0.4.0
#   [3349acd9] + ProtoBuf v0.8.0
#   [a223df75] + Reactive v0.8.3
#   [24249f21] + SymPy v1.0.11
#   [1986cc42] + Unitful v0.18.0
#   Building CMake → `/srv/julia/pkg/packages/CMake/nSK2r/deps/build.log`
#   Building Blosc → `/srv/julia/pkg/packages/Blosc/lzFr0/deps/build.log`
#   Building HDF5 ─→ `/srv/julia/pkg/packages/HDF5/Zh9on/deps/build.log`

# %%
df=DataFrame(xs=1:N,ys=1:N |> x->sin.(2pi*x/N),zs=1:N |> x->cos.(2pi*x/N))
display(df)
df1 = ( @from d in df begin
        @where d.ys>.5
        @select d
        @collect DataFrame
        end )
display(df1)
CSV.write("df1.csv",df1)
@df stack(df,[:ys,:zs]) plot(:xs,:value,group=:variable)
# Out:
# 100×3 DataFrame
# │ Row │ xs    │ ys           │ zs       │
# │     │ Int64 │ Float64      │ Float64  │
# ├─────┼───────┼──────────────┼──────────┤
# │ 1   │ 1     │ 0.0627905    │ 0.998027 │
# │ 2   │ 2     │ 0.125333     │ 0.992115 │
# │ 3   │ 3     │ 0.187381     │ 0.982287 │
# │ 4   │ 4     │ 0.24869      │ 0.968583 │
# │ 5   │ 5     │ 0.309017     │ 0.951057 │
# │ 6   │ 6     │ 0.368125     │ 0.929776 │
# │ 7   │ 7     │ 0.425779     │ 0.904827 │
# │ 8   │ 8     │ 0.481754     │ 0.876307 │
# │ 9   │ 9     │ 0.535827     │ 0.844328 │
# │ 10  │ 10    │ 0.587785     │ 0.809017 │
# ⋮
# │ 90  │ 90    │ -0.587785    │ 0.809017 │
# │ 91  │ 91    │ -0.535827    │ 0.844328 │
# │ 92  │ 92    │ -0.481754    │ 0.876307 │
# │ 93  │ 93    │ -0.425779    │ 0.904827 │
# │ 94  │ 94    │ -0.368125    │ 0.929776 │
# │ 95  │ 95    │ -0.309017    │ 0.951057 │
# │ 96  │ 96    │ -0.24869     │ 0.968583 │
# │ 97  │ 97    │ -0.187381    │ 0.982287 │
# │ 98  │ 98    │ -0.125333    │ 0.992115 │
# │ 99  │ 99    │ -0.0627905   │ 0.998027 │
# │ 100 │ 100   │ -2.44929e-16 │ 1.0      │
# 33×3 DataFrame
# │ Row │ xs    │ ys       │ zs        │
# │     │ Int64 │ Float64  │ Float64   │
# ├─────┼───────┼──────────┼───────────┤
# │ 1   │ 9     │ 0.535827 │ 0.844328  │
# │ 2   │ 10    │ 0.587785 │ 0.809017  │
# │ 3   │ 11    │ 0.637424 │ 0.770513  │
# │ 4   │ 12    │ 0.684547 │ 0.728969  │
# │ 5   │ 13    │ 0.728969 │ 0.684547  │
# │ 6   │ 14    │ 0.770513 │ 0.637424  │
# │ 7   │ 15    │ 0.809017 │ 0.587785  │
# │ 8   │ 16    │ 0.844328 │ 0.535827  │
# │ 9   │ 17    │ 0.876307 │ 0.481754  │
# │ 10  │ 18    │ 0.904827 │ 0.425779  │
# ⋮
# │ 23  │ 31    │ 0.929776 │ -0.368125 │
# │ 24  │ 32    │ 0.904827 │ -0.425779 │
# │ 25  │ 33    │ 0.876307 │ -0.481754 │
# │ 26  │ 34    │ 0.844328 │ -0.535827 │
# │ 27  │ 35    │ 0.809017 │ -0.587785 │
# │ 28  │ 36    │ 0.770513 │ -0.637424 │
# │ 29  │ 37    │ 0.728969 │ -0.684547 │
# │ 30  │ 38    │ 0.684547 │ -0.728969 │
# │ 31  │ 39    │ 0.637424 │ -0.770513 │
# │ 32  │ 40    │ 0.587785 │ -0.809017 │
# │ 33  │ 41    │ 0.535827 │ -0.844328 │
